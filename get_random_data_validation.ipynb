# %%
import pandas as pd
 
data = pd.read_csv('major_data_cleaned_300.csv')
data
# Out:
#                                                   NAMA  PEMINAT 2023  \
# 0                                            MANAJEMEN         84340
# 1                                            AKUNTANSI         63257
# 2                                      ILMU KOMUNIKASI         57627
# 3                                            PSIKOLOGI         54772
# 4                                           ILMU HUKUM         44576
# ..                                                 ...           ...
# 289                               TEKNOLOGI SAINS DATA           645
# 290  FAKULTAS MATEMATIKA DAN ILMU PENGETAHUAN ALAM ...           644
# 291      PENDIDIKAN TEKNOLOGI INFORMATIKA DAN KOMPUTER           644
# 292                                TEKNOLOGI BIOPROSES           639
# 293  FAKULTAS MATEMATIKA DAN ILMU PENGETAHUAN ALAM ...           637
#
#                                            Description  \
# 0     MANAJEMEN adalah jurusan yang mempelajari teo...
# ...

# %%
sample_data = data.sample(70)

# %%
sample_data
# Out:
#                                               NAMA  PEMINAT 2023  \
# 220                                TEKNIK MATERIAL           942
# 111                           AKUNTANSI PERPAJAKAN          2112
# 150                         PENDIDIKAN AGAMA ISLAM          1538
# 224                 ILMU ADMINISTRASI NIAGA/BISNIS           925
# 291  PENDIDIKAN TEKNOLOGI INFORMATIKA DAN KOMPUTER           644
# ..                                             ...           ...
# 284                                BIMB. KONSELING           673
# 264                           KESEHATAN LINGKUNGAN           739
# 159      PEND. GURU SEKOLAH DASAR (PGSD) SURAKARTA          1436
# 99                             HUBUNGAN MASYARAKAT          2314
# 27                                  BISNIS DIGITAL         11464
#
#                                            Description  \
# 220   Teknik Material adalah jurusan kuliah yang me...
# 111  Jurusan Akuntansi Perpajakan melibatkan studi ...
# ...

# %%
# export to csv
sample_data.to_csv('sample_data_validation.csv', index=False)
