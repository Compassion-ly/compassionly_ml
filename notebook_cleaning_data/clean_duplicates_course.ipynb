# %%
import pandas as pd

df = pd.read_csv('../dataset/course.csv')
df.head()
# Out:
#    ID                    Mata Kuliah      Major  \
# 0   1             Manajemen Keuangan  MANAJEMEN
# 1   1             Manajemen Keuangan  MANAJEMEN
# 2   1             Manajemen Keuangan  MANAJEMEN
# 3   1             Manajemen Keuangan  MANAJEMEN
# 4   1  Manajemen Sumber Daya Manusia  MANAJEMEN
#
#                                          Description
# 0  Course introduction: \n\nSelamat datang di mat...
# 1  Manajemen Keuangan (NK) adalah mata kuliah yan...
# 2  Course introduction: \n\nSelamat datang di mat...
# 3  Manajemen Keuangan (NK) adalah mata kuliah yan...
# 4  Course Introduction:\n\nSelamat datang di mata...

# %%
df_cleaned = df.drop_duplicates(subset=['Mata Kuliah', 'Major'], keep='first')
df_cleaned
# Out:
#        ID                       Mata Kuliah                  Major  \
# 0       1                Manajemen Keuangan              MANAJEMEN
# 4       1     Manajemen Sumber Daya Manusia              MANAJEMEN
# 5       1               Manajemen Pemasaran              MANAJEMEN
# 6       1             Manajemen Operasional              MANAJEMEN
# 7       1                Manajemen Strategi              MANAJEMEN
# ...   ...                               ...                    ...
# 1300  240           Dasar-dasar Elektronika  TEKNIK TENAGA LISTRIK
# 1301  240          Teknik Instalasi Listrik  TEKNIK TENAGA LISTRIK
# 1302  240  Sistem Pembangkit Tenaga Listrik  TEKNIK TENAGA LISTRIK
# 1303  240   Pengantar Sistem Tenaga Listrik  TEKNIK TENAGA LISTRIK
# 1304  240           Teknik Proteksi Listrik  TEKNIK TENAGA LISTRIK
#
#                                             Description
# 0     Course introduction: \n\nSelamat datang di mat...
# ...

# %%
df_cleaned.to_csv('../dataset/course_cleaned.csv', index=False)
